# %% [markdown]
# <a href="https://colab.research.google.com/github/Darkblazer21/EcoVision_PAS_2023/blob/test/notebooks/EcoVison_Test_Collab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
from IPython.display import display
# %matplotlib inline
from shapely.geometry import Point
import pandas as np

# %%
states = gpd.read_file("/content/drive/MyDrive/senegal-and-gambia-latest-free.shp/gis_osm_landuse_a_free_1.shp")

# %%
states.head(25)
# Out:
#       osm_id  code             fclass  \
# 0   15933712  7201             forest
# 1    4103595  7201             forest
# 2    4103596  7201             forest
# 3    4114010  7217              scrub
# 4    4114713  7218              grass
# 5    4114730  7218              grass
# 6    4119130  7201             forest
# 7    4121789  7229           farmland
# 8    4121860  7217              scrub
# 9    4122754  7229           farmland
# 10   4123640  7203        residential
# 11   4125881  7229           farmland
# 12   4125983  7229           farmland
# 13  23513105  7211  recreation_ground
# 14  25489069  7229           farmland
# 15  27294607  7203        residential
# 16  27811247  7202               park
# 17  29403304  7212             retail
# 18  30674535  7213           military
# 19  31462760  7203        residential
# 20  31464198  7203        residential
# 21  31464775  7203        residential
# 22  31464926  7203        residential
# ...

# %%
states.plot()
# Out:
# <Axes: >

# %%
classes = states['fclass'].unique()

# %%
for class_name in classes:
    print(class_name)
# Out:
# forest
# scrub
# grass
# farmland
# residential
# recreation_ground
# park
# retail
# military
# commercial
# cemetery
# industrial
# nature_reserve
# orchard
# allotments
# quarry
# heath
# farmyard
# meadow

# %%
# Liste des classes que l'on veut visualiser sur la carte
classes_to_display = ["forest", "nature_reserve", "scrub", "grass", "meadow"]

# %%
# Filtrer le DataFrame géospatial pour inclure uniquement les classes spécifiées
filtered_states = states[states['fclass'].isin(classes_to_display)]

# %%
# Tracer le résultat filtré
filtered_states.plot()
# Out:
# <Axes: >

# %%
# Visualiser uniquement les forêts et les réserves naturelles
classes_to_display = ["forest", "nature_reserve"]

# %%
filtered_states = states[states['fclass'].isin(classes_to_display)]

# %%
filtered_states.plot()
# Out:
# <Axes: >

# %%
states = gpd.read_file("/content/drive/MyDrive/WDPA_WDOECM_Sep2023_Public_SEN_shp/WDPA_WDOECM_Sep2023_Public_SEN_shp_0/WDPA_WDOECM_Sep2023_Public_SEN_shp-polygons.shp")

# %%
states.head(25)
# Out:
#       WDPAID WDPA_PID PA_DEF                            NAME  \
# 0      865.0      865      1                    Niokolo Koba
# 1      866.0      866      1                 Delta du Saloum
# 2      867.0      867      1               Oiseaux du Djoudj
# 3      868.0      868      1                 Basse-Casamance
# 4      869.0      869      1              Langue de Barbarie
# 5      870.0      870      1            Iles de la Madeleine
# 6     2332.0     2332      1                       Ferlo-Sud
# 7     2333.0     2333      1                      Ferlo-Nord
# 8     2578.0     2578      1  Djoudj National Bird Sanctuary
# 9     2580.0     2580      1      Niokolo-Koba National Park
# 10    3044.0     3044      1                 Delta du Saloum
# 11    3045.0     3045      1   Parc national du Niokolo-Koba
# 12    3217.0     3217      1                       Kalissaye
# 13    5178.0     5178      1                          Ndiael
# ...

# %%
states.plot()
# Out:
# <Axes: >

# %%
classes = states['DESIG'].unique()

# %%
for class_name in classes:
    print(class_name)
# Out:
# Parc National
# Wildlife Reserve
# Réserve de Faune
# World Heritage Site (natural or mixed)
# UNESCO-MAB Biosphere Reserve
# Réserve Spéciale d’Oiseaux
# Réserve Spéciale de Faune
# Réserve Naturelle
# Forest Reserve
# Ramsar Site, Wetland of International Importance
# Réserve Sylvo-pastorale

# %%
states.shape
# Out:
# (45, 31)

# %%
classes_to_display = ["Parc National", "Wildlife Reserve", "Réserve Naturelle", "Forest Reserve", "Réserve Sylvo-pastorale"]

# %%
filtered_states = states[states['DESIG'].isin(classes_to_display)]

# %%
filtered_states.plot()
# Out:
# <Axes: >

# %%
classes_to_display = ["Réserve Naturelle", "Forest Reserve", "Réserve Sylvo-pastorale"]

# %%
filtered_states = states[states['DESIG'].isin(classes_to_display)]

# %%
filtered_states.plot()
# Out:
# <Axes: >

# %%
# suite du fichier
states = gpd.read_file("/content/drive/MyDrive/WDPA_WDOECM_Sep2023_Public_SEN_shp/WDPA_WDOECM_Sep2023_Public_SEN_shp_1/WDPA_WDOECM_Sep2023_Public_SEN_shp-polygons.shp")

# %%
states.shape
# Out:
# (45, 31)

# %%
states.head(25)
# Out:
#       WDPAID WDPA_PID PA_DEF                     NAME  \
# 0   352630.0   352630      1           Foret de Thies
# 1   352631.0   352631      1                   Mbegue
# 2   352632.0   352632      1          Foret de Bandia
# 3   352633.0   352633      1              Siné-Saloum
# 4   352634.0   352634      1           Foret de Panal
# 5   352635.0   352635      1         Foret de Narangs
# 6   352636.0   352636      1     Foret de Tamba- Nord
# 7   352637.0   352637      1       Foret de Birkelane
# 8   352638.0   352638      1         Foret de Goudiri
# 9   352639.0   352639      1          Foret de Kassas
# 10  352640.0   352640      1           Foret de Delbi
# 11  352641.0   352641      1       Foret de Bala- Est
# 12  352642.0   352642      1       Foret des Paniates
# 13  352643.0   352643      1           Foret de Sagna
# 14  352644.0   352644      1     Foret de Malem Niani
# 15  352645.0   352645      1           Foret de Wélor
# ...

# %%
states.plot()
# Out:
# <Axes: >

# %%
classes = states['DESIG'].unique()

# %%
for class_name in classes:
    print(class_name)
# Out:
# Forest Reserve
# Réserve Sylvo-pastorale

# %%
states = gpd.read_file("/content/drive/MyDrive/WDPA_WDOECM_Sep2023_Public_SEN_shp/WDPA_WDOECM_Sep2023_Public_SEN_shp_2/WDPA_WDOECM_Sep2023_Public_SEN_shp-polygons.shp")

# %%
states.shape
# Out:
# (43, 31)

# %%
states.plot()
# Out:
# <Axes: >

# %%
classes = states['DESIG'].unique()

# %%
for class_name in classes:
    print(class_name)
# Out:
# Forest Reserve
# Aire Marine Protégée
# Ramsar Site, Wetland of International Importance
# Réserve Naturelle Communautaire
# Réserve Naturelle Urbaine

# %%
classes_to_display = ["Forest Reserve"]

# %%
filtered_states = states[states['DESIG'].isin(classes_to_display)]

# %%
filtered_states.plot()
# Out:
# <Axes: >

# %%
filtered_states.shape
# Out:
# (25, 31)
